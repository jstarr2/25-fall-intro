# %%
from datascience import *
import numpy as np
import warnings
warnings.filterwarnings("ignore")

# %matplotlib inline
import matplotlib.pyplot as plots
plots.style.use('fivethirtyeight')
plots.rcParams["patch.force_edgecolor"] = True

# %% [markdown]
# # Bar Charts

# %%
# The flavor of ice cream is a categorical variable
icecream = Table().with_columns(
    'Flavor', make_array('Chocolate', 'Strawberry', 'Vanilla'),
    'Number of Cartons', make_array(16, 5, 9)
)
icecream
# Out:
# Flavor     | Number of Cartons
# Chocolate  | 16
# Strawberry | 5
# Vanilla    | 9

# %%
icecream.barh('Flavor', 'Number of Cartons')
# or simply
# icecream.barh('Flavor')

# %%
# Even better if you sort first
icecream = icecream.sort('Number of Cartons', descending = True)
icecream.barh('Flavor')

# %% [markdown]
# # Practice
# Plot the ten movies with the *lowest* adjusted gross as a bar chart.
# The category is the name of the movie.
# The "frequencies" are the adjusted gross.

# %%
# Highest grossing movies as of 2017
top_movies = Table.read_table('top_movies_2017.csv')
top_movies
# Out:
# Title                            | Studio          | Gross     | Gross (Adjusted) | Year
# Gone with the Wind               | MGM             | 198676459 | 1796176700       | 1939
# Star Wars                        | Fox             | 460998007 | 1583483200       | 1977
# The Sound of Music               | Fox             | 158671368 | 1266072700       | 1965
# E.T.: The Extra-Terrestrial      | Universal       | 435110554 | 1261085000       | 1982
# Titanic                          | Paramount       | 658672302 | 1204368000       | 1997
# The Ten Commandments             | Paramount       | 65500000  | 1164590000       | 1956
# Jaws                             | Universal       | 260000000 | 1138620700       | 1975
# Doctor Zhivago                   | MGM             | 111721910 | 1103564200       | 1965
# The Exorcist                     | Warner Brothers | 232906145 | 983226600        | 1973
# Snow White and the Seven Dwarves | Disney          | 184925486 | 969010000        | 1937
# ... (190 rows omitted)

# %%
top_movies=top_movies.sort('Gross (Adjusted)')
worst_ten=top_movies.take(np.arange(10))
worst_ten.barh('Title', 'Gross (Adjusted)')

# %% [markdown]
# # Grouping

# %%
top_movies
# Out:
# Title                              | Studio          | Gross     | Gross (Adjusted) | Year
# Who Framed Roger Rabbit            | Buena Vista     | 156452370 | 338409100        | 1988
# Suicide Squad                      | Warner Brothers | 325100054 | 339411900        | 2016
# The Firm                           | Paramount       | 158348367 | 340028200        | 1993
# Batman v Superman: Dawn of Justice | Warner Brothers | 330360194 | 340137000        | 2016
# 9 to 5                             | Fox             | 103290500 | 341357800        | 1980
# What's Up, Doc?                    | Warner Brothers | 66000000  | 345141200        | 1972
# The Twilight Saga: New Moon        | Sum.            | 296623634 | 345910600        | 2009
# Superman II                        | Warner Brothers | 108185706 | 345960800        | 1981
# Signs                              | Buena Vista     | 227966634 | 348787100        | 2002
# Batman Returns                     | Warner Brothers | 162831698 | 348813000        | 1992
# ... (190 rows omitted)

# %%
studio_distribution = studios.group('Studio')
studio_distribution
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 studio_distribution = studios.group('Studio')
#       2 studio_distribution
#
# NameError: name 'studios' is not defined

# %%
studio_distribution = studio_distribution.sort('count', descending = True)
studio_distribution.barh('Studio')

# %% [markdown]
# # Practice
# Group the movies in top_movies by release year and plot the resulting frequencies.

# %% [markdown]
# # Binning
# Lets put the movies into five-year bins and plot again.

# %%
# Generate 10 equally spaced bins, but it's not great for a variable like Year
auto_binned_movies = top_movies.bin('Year', bins = 10)
auto_binned_movies.show()
# Out:
# <table border="1" class="dataframe">
#     <thead>
#         <tr>
#             <th>bin</th> <th>Year count</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>1921  </td> <td>1         </td>
#         </tr>
#         <tr>
#             <td>1930.6</td> <td>3         </td>
#         </tr>
#         <tr>
#             <td>1940.2</td> <td>6         </td>
#         </tr>
#         <tr>
#             <td>1949.8</td> <td>13        </td>
#         </tr>
#         <tr>
#             <td>1959.4</td> <td>18        </td>
#         </tr>
#         <tr>
#             <td>1969  </td> <td>26        </td>
#         </tr>
#         <tr>
#             <td>1978.6</td> <td>24        </td>
#         </tr>
#         <tr>
#             <td>1988.2</td> <td>28        </td>
#         </tr>
#         <tr>
#             <td>1997.8</td> <td>40        </td>
#         </tr>
#         <tr>
#             <td>2007.4</td> <td>41        </td>
#         </tr>
#         <tr>
#             <td>2017  </td> <td>0         </td>
#         </tr>
#     </tbody>
# </table>

# %%
# Use arange to create specific bins
max_year = max(top_movies.column('Year'))
min_year = min(top_movies.column('Year'))
print(min_year, max_year)
# Out:
# 1921 2017

# %%
year_bins = np.arange(1921, 2018, 9)
year_bins
# Out:
# array([1921, 1930, 1939, 1948, 1957, 1966, 1975, 1984, 1993, 2002, 2011])

# %%
# Appears to have no movies released after 2011 because the last bin is always empty.
manual_binned_movies = top_movies.bin('Year', bins = year_bins)
manual_binned_movies.show()
# Out:
# <table border="1" class="dataframe">
#     <thead>
#         <tr>
#             <th>bin</th> <th>Year count</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>1921</td> <td>1         </td>
#         </tr>
#         <tr>
#             <td>1930</td> <td>1         </td>
#         </tr>
#         <tr>
#             <td>1939</td> <td>8         </td>
#         </tr>
#         <tr>
#             <td>1948</td> <td>10        </td>
#         </tr>
#         <tr>
#             <td>1957</td> <td>16        </td>
#         </tr>
#         <tr>
#             <td>1966</td> <td>20        </td>
#         </tr>
#         <tr>
#             <td>1975</td> <td>22        </td>
#         </tr>
#         <tr>
#             <td>1984</td> <td>25        </td>
#         </tr>
#         <tr>
#             <td>1993</td> <td>30        </td>
#         </tr>
#         <tr>
#             <td>2002</td> <td>39        </td>
#         </tr>
#         <tr>
#             <td>2011</td> <td>0         </td>
#         </tr>
#     </tbody>
# </table>

# %%
# We can fix it by making sure the last number incorporates our max year.
year_bins = np.arange(1921, 2021, 9)
manual_binned_movies = top_movies.bin('Year', bins = year_bins)
manual_binned_movies.show()
# Out:
# <table border="1" class="dataframe">
#     <thead>
#         <tr>
#             <th>bin</th> <th>Year count</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>1921</td> <td>1         </td>
#         </tr>
#         <tr>
#             <td>1930</td> <td>1         </td>
#         </tr>
#         <tr>
#             <td>1939</td> <td>8         </td>
#         </tr>
#         <tr>
#             <td>1948</td> <td>10        </td>
#         </tr>
#         <tr>
#             <td>1957</td> <td>16        </td>
#         </tr>
#         <tr>
#             <td>1966</td> <td>20        </td>
#         </tr>
#         <tr>
#             <td>1975</td> <td>22        </td>
#         </tr>
#         <tr>
#             <td>1984</td> <td>25        </td>
#         </tr>
#         <tr>
#             <td>1993</td> <td>30        </td>
#         </tr>
#         <tr>
#             <td>2002</td> <td>37        </td>
#         </tr>
#         <tr>
#             <td>2011</td> <td>30        </td>
#         </tr>
#         <tr>
#             <td>2020</td> <td>0         </td>
#         </tr>
#     </tbody>
# </table>

# %%
manual_binned_movies.barh('bin')

# %% [markdown]
# # Practice
# Find reasonable bin sizes for adjusted gross. Aim for ten or so nonempty bins.
# Bin the data and plot the resulting frequencies.

# %%
min_adj_gross= min(top_movies.column('Gross (Adjusted)'))
max_adj_gross= max(top_movies.column('Gross (Adjusted)'))
print(max_adj_gross-min_adj_gross /10)
gross_bins= np.arange(300000000, 1800000000, 1500000000 )
# Out:
# 1762335790.0
